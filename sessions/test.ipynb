# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
data = pd.read_csv('../data/test/test.csv')

# %%
print(data.head())
# Out:
#           t      x(t)
# 0  0.000000 -171.1125
# 1  0.016950 -167.6948
# 2  0.033899 -163.9844
# 3  0.050849 -159.3855
# 4  0.067798 -153.9923

# %%
series = pd.Series(data['x(t)'])
A_max = max(series.abs())
data["x(t) / A_max"] = data['x(t)'] / A_max

# %%
print(data.head())
# Out:
#           t      x(t)  x(t) / A_max
# 0  0.000000 -171.1125     -0.846569
# 1  0.016950 -167.6948     -0.829660
# 2  0.033899 -163.9844     -0.811303
# 3  0.050849 -159.3855     -0.788550
# 4  0.067798 -153.9923     -0.761867
